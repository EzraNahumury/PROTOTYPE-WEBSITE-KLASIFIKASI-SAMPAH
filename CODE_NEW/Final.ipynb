# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Input, MaxPooling2D, Flatten, Dropout, Conv2D
import os
from sklearn.model_selection import train_test_split
import collections
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from io import BytesIO
from IPython.display import FileLink
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = "/content/drive/MyDrive/SKRIPSI/train"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# %%
def get_dataset_path(base_path):
    classes = sorted(os.listdir(base_path))
    file_paths = []
    labels = []

    for i, class_name in enumerate(classes):
        class_dir = os.path.join(base_path, class_name)
        for file_name in os.listdir(class_dir):
            if file_name.lower().endswith(('.jpg', '.jpeg', '.png')):
                file_paths.append(os.path.join(class_dir, file_name))
                labels.append(i)

    return file_paths, labels, classes

# %%
file_paths, labels, class_names = get_dataset_path(base_path)

print(f"Found {len(file_paths)} images in {len(class_names)} classes.")
# Out:
# Found 12669 images in 6 classes.

# %%
from pathlib import Path
import pandas as pd



# Hitung jumlah file per kelas
main_folder_path = Path(base_path)
all_folders = [d for d in main_folder_path.glob('*/') if d.is_dir()]  # Hanya subfolder langsung

data = []
for folder in all_folders:
    folder_name = folder.name
    # Hitung hanya file gambar (modifikasi pattern sesuai kebutuhan)
    file_count = len([
        f for f in folder.glob('*')
        if f.is_file() and f.suffix.lower() in ['.jpg', '.jpeg', '.png']
    ])
    data.append({'Kelas': folder_name, 'Jumlah Sample': file_count})

# Buat DataFrame dan tampilkan
count_df = pd.DataFrame(data).sort_values('Jumlah Sample', ascending=False)
count_df = count_df.set_index('Kelas')
print("\nDistribusi Kelas:")
print(count_df)
print(f"\nTotal Sample: {count_df['Jumlah Sample'].sum()}")

# Visualisasi (opsional)
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
count_df['Jumlah Sample'].plot(kind='bar')
plt.title('Distribusi Jumlah Sample per Kelas')
plt.ylabel('Jumlah Sample')
plt.xticks(rotation=45)
plt.show()
# Out:
# Distribusi Kelas:
#          Jumlah Sample
# Kelas
# Residu            3044
# Plastik           2122
# Kertas            2055
# Logam             1978
# Kaca              1956
# Kardus            1514
#
# Total Sample: 12669

# %%
def plot_images(item_dir):
    all_item_dirs = os.listdir(item_dir)
    item_files = [os.path.join(item_dir, file) for file in all_item_dirs][:5]
    plt.figure(figsize=(10, 10))
    for image_id, image_path in enumerate(item_files):
        plt.subplot(1, 5, image_id+1)
        img = plt.imread(image_path)
        plt.axis('off')
        plt.imshow(img)
        plt.title(os.path.basename(item_dir), fontsize=8)

categories = ["Kardus", "Kaca", "Logam", "Kertas", "Plastik", "Residu"]
for category in categories:
    plot_images(os.path.join(base_path, category))

# %% [markdown]
# **Pre-Processing**

# %%
def prep_image(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)
    img = img / 255.0
    return img, label

# %%
# ============================================================
# Visualisasi hasil Preprocessing (5 gambar per kelas)
# ============================================================
import matplotlib.pyplot as plt

num_samples = 5  # jumlah gambar per kelas

plt.figure(figsize=(15, len(class_names) * 3))

for class_id, class_name in enumerate(class_names):
    # Ambil file path untuk kelas tertentu
    sample_images = [fp for fp, lb in zip(file_paths, labels) if lb == class_id][:num_samples]

    for i, img_path in enumerate(sample_images):
        # Apply preprocessing
        img_tensor, _ = prep_image(img_path, class_id)
        img = img_tensor.numpy()

        # Plot di grid: baris = kelas, kolom = gambar
        plt.subplot(len(class_names), num_samples, class_id * num_samples + i + 1)
        plt.imshow(img)
        plt.axis("off")
        if i == 0:  # kasih label kelas di gambar pertama
            plt.ylabel(class_name, fontsize=12)

plt.suptitle("Hasil Preprocessing (5 gambar per kelas)", fontsize=20)
plt.tight_layout()
plt.show()

# %%
train_paths, test_paths, train_labels, test_labels = train_test_split(
    file_paths, labels, test_size=0.2, random_state=42, stratify=labels
)
val_paths, test_paths, val_labels, test_labels = train_test_split(
    test_paths, test_labels, test_size=0.5, random_state=42, stratify=test_labels
)

# %%
def create_dataset(file_paths, labels):
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))
    dataset = dataset.map(prep_image, num_parallel_calls = tf.data.AUTOTUNE)
    dataset = dataset.shuffle(buffer_size = 1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
train_dataset = create_dataset(train_paths, train_labels)
test_dataset = create_dataset(test_paths, test_labels)
val_dataset = create_dataset(val_paths, val_labels)

# %% [markdown]
# **AUGMENTASI**

# %%
def augment_image(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, max_delta=0.2)
    return img, label

train_dataset = train_dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)

# %%
# ============================================================
# Visualisasi Perbandingan Preprocessing vs Augmentasi
# (1 gambar per kelas)
# ============================================================
import matplotlib.pyplot as plt

plt.figure(figsize=(15, len(class_names) * 3))

for class_id, class_name in enumerate(class_names):
    # Ambil 1 gambar dari kelas tertentu
    img_path = [fp for fp, lb in zip(file_paths, labels) if lb == class_id][0]

    # Apply preprocessing (normal)
    img_tensor, _ = prep_image(img_path, class_id)
    img_normal = img_tensor.numpy()

    # Apply augmentasi
    aug_img, _ = augment_image(img_tensor, class_id)
    img_aug = aug_img.numpy()

    # Plot gambar normal (baris 1)
    plt.subplot(2, len(class_names), class_id + 1)
    plt.imshow(img_normal)
    plt.axis("off")
    plt.title(f"{class_name}\n(Normal)")

    # Plot gambar augmented (baris 2)
    plt.subplot(2, len(class_names), len(class_names) + class_id + 1)
    plt.imshow(img_aug)
    plt.axis("off")
    plt.title(f"{class_name}\n(Augmented)")

plt.suptitle("Perbandingan Gambar Normal vs Augmentasi", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.34086406..1.1663983].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.088106535..0.9117259].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.23616984..1.1620374].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.17921232..0.7599502].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.029033117..0.8873847].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0007609129..0.97780645].

# %% [markdown]
# **MODEL**

# %%
def build_model(num_classes):
    base_model = MobileNetV2(include_top=False, weights='imagenet', input_shape=IMG_SIZE + (3,))
    base_model.trainable = True

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    return model

# %%
num_classes = len(class_names)
model = build_model(num_classes)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,726 (9.24 MB)
#  Trainable params: 2,388,614 (9.11 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
from google.colab import drive
import os
import tensorflow as tf

# === 1. Hitung Class Weights ===
# pastikan train_labels = array 1D label kelas (bukan one-hot)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)
class_weights = dict(enumerate(class_weights))

# === 2. Training Model ===
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=20,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr]
)

# === 3. Mount Google Drive ===
drive.mount('/content/drive')

# === 4. Simpan Model ke Google Drive hanya dalam format TFLite ===
save_dir = '/content/drive/MyDrive/Colab Notebooks/NEW'
os.makedirs(save_dir, exist_ok=True)

tflite_path = os.path.join(save_dir, "model_fix.tflite")

# Convert ke TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # opsional untuk kecilkan ukuran
tflite_model = converter.convert()

# Simpan ke file .tflite
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f" Model TFLite disimpan di: {tflite_path}")
# Out:
# Epoch 1/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 823s 2s/step - accuracy: 0.2802 - loss: 1.9002 - val_accuracy: 0.5651 - val_loss: 1.1166 - learning_rate: 1.0000e-05
# Epoch 2/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 54ms/step - accuracy: 0.5817 - loss: 1.0916 - val_accuracy: 0.7238 - val_loss: 0.7659 - learning_rate: 1.0000e-05
# Epoch 3/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.6971 - loss: 0.8324 - val_accuracy: 0.7916 - val_loss: 0.5978 - learning_rate: 1.0000e-05
# Epoch 4/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - accuracy: 0.7672 - loss: 0.6652 - val_accuracy: 0.8208 - val_loss: 0.5106 - learning_rate: 1.0000e-05
# Epoch 5/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - accuracy: 0.8001 - loss: 0.5720 - val_accuracy: 0.8374 - val_loss: 0.4429 - learning_rate: 1.0000e-05
# Epoch 6/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - accuracy: 0.8191 - loss: 0.5127 - val_accuracy: 0.8532 - val_loss: 0.3961 - learning_rate: 1.0000e-05
# Epoch 7/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.8459 - loss: 0.4483 - val_accuracy: 0.8698 - val_loss: 0.3616 - learning_rate: 1.0000e-05
# Epoch 8/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.8623 - loss: 0.4013 - val_accuracy: 0.8761 - val_loss: 0.3367 - learning_rate: 1.0000e-05
# Epoch 9/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.8757 - loss: 0.3647 - val_accuracy: 0.8871 - val_loss: 0.3129 - learning_rate: 1.0000e-05
# Epoch 10/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.8845 - loss: 0.3306 - val_accuracy: 0.8871 - val_loss: 0.3019 - learning_rate: 1.0000e-05
# Epoch 11/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9008 - loss: 0.2965 - val_accuracy: 0.9006 - val_loss: 0.2833 - learning_rate: 1.0000e-05
# Epoch 12/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9090 - loss: 0.2737 - val_accuracy: 0.8966 - val_loss: 0.2695 - learning_rate: 1.0000e-05
# Epoch 13/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.9186 - loss: 0.2452 - val_accuracy: 0.9061 - val_loss: 0.2600 - learning_rate: 1.0000e-05
# Epoch 14/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9243 - loss: 0.2193 - val_accuracy: 0.9092 - val_loss: 0.2513 - learning_rate: 1.0000e-05
# Epoch 15/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9335 - loss: 0.2008 - val_accuracy: 0.9116 - val_loss: 0.2405 - learning_rate: 1.0000e-05
# Epoch 16/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9266 - loss: 0.2037 - val_accuracy: 0.9132 - val_loss: 0.2369 - learning_rate: 1.0000e-05
# Epoch 17/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9434 - loss: 0.1767 - val_accuracy: 0.9140 - val_loss: 0.2361 - learning_rate: 1.0000e-05
# Epoch 18/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.9526 - loss: 0.1487 - val_accuracy: 0.9140 - val_loss: 0.2285 - learning_rate: 1.0000e-05
# Epoch 19/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9510 - loss: 0.1489 - val_accuracy: 0.9211 - val_loss: 0.2233 - learning_rate: 1.0000e-05
# Epoch 20/20
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9528 - loss: 0.1367 - val_accuracy: 0.9155 - val_loss: 0.2246 - learning_rate: 1.0000e-05
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved artifact at '/tmp/tmpcba_7i7z'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   133710535443664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535444816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535445008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535444240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535443472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710541668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535445200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535445968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535445584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535442512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535444624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535447120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535447312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535443856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535444432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535447888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535450000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535450192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535449040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535448464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535446928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535451344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535451536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535450768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535448272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535450384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535448848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535449808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535450960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535452496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535451920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535452112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535452304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535451152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535453456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535452880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535449232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535454800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535454992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535454032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535454608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535456144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535454224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535456528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535453648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535457104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535457296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535458064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535453840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535455376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535458448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710535456912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540178640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540178448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540178064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540179216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540177680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540178832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540179024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540178256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540180176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540179600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540179984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540177872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540181136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540180752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540177488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540181520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540181712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540181904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540183056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540182480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540182672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540182864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540180368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540184016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540183440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540183632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540183824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540181328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540184976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540184592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540182288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540185936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540185360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540183248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540186896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540186512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540184208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540185168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540188816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540188240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540188432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540186128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540189776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540189200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540189392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540189584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540190736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540191696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540191120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540191312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540191504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540192656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540192272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540193616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540190928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540193424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710540191888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538245712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538245904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538245136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538244560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538244368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538245520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538245328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538244944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538246864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538246288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538246480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538246672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538247824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538247248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538247440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538247632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538244752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538248784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538248208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538248400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538248592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538246096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538249744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538249168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538249360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538249552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538247056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538250704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538250128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538250320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538250512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538248016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538251664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538251088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538251280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538251472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538248976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538252624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538252048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538252240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538252432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538249936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538253584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538253008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538253200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538253392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538250896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538254544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538253968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538254160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538254352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538251856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538255504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538254928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538255120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538255312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538252816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538256464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538255888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538256080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538256272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538253776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538257424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538256848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538257040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538257232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538254736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538258384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538257808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538258000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538258192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538255696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538259344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538258768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538258960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538259728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538256656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538260304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538259152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538259920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538257616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538260112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538259536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710538258576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522631760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522631952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522631184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522630608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522630416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522631568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522631376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522630992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522632912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522632336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522632528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522632720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522630224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522633872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522633296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522633488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522633680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522630800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522634832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522634256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522634448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522634640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522632144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522635792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522637520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133710522636752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#  Model TFLite disimpan di: /content/drive/MyDrive/Colab Notebooks/NEW/model_fix.tflite

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 80s 410ms/step - accuracy: 0.9095 - loss: 0.2744
# Test Accuracy: 91.79%

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

plot_loss_acc(history)

# %%
import keras.utils as ku

# %%
# Dictionary untuk klasifikasi
number_to_class = {
    0: 'Besi',
    1: 'Kaca',
    2: 'Kardus',
    3: 'Kertas',
    4: 'Plastik',
    5: 'Residu'
}

# Load dan preprocess gambar
test_img = 'coba.jpg'
img = ku.load_img(test_img, target_size=(224, 224))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img) / 255.0

# Prediksi dengan model
prediction = model.predict(img[np.newaxis, ...])

# Hasil klasifikasi
print("Probability:", np.max(prediction[0], axis=-1))
predicted_class = number_to_class[np.argmax(prediction[0], axis=-1)]
print("Classified:", predicted_class, '\n')

# Tampilkan gambar
plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Probability: 0.99862975
# Classified: Residu

# %%
import os
import shutil
import random

# Path dataset utama
dataset_path = "/content/drive/MyDrive/SKRIPSI"
train_path = os.path.join(dataset_path, "train")
test_path = os.path.join(dataset_path, "test")


if not os.path.exists(train_path):
    raise FileNotFoundError(f"Path '{train_path}' tidak ditemukan. Periksa lokasi dataset!")


if not os.path.exists(test_path):
    os.makedirs(test_path)


test_ratio = 0.2  # 20% dari total data


for class_name in os.listdir(train_path):
    class_train_path = os.path.join(train_path, class_name)
    class_test_path = os.path.join(test_path, class_name)


    if not os.path.exists(class_test_path):
        os.makedirs(class_test_path)


    images = [img for img in os.listdir(class_train_path) if img.endswith(('.jpg', '.png', '.jpeg'))]


    if len(images) == 0:
        print(f"Peringatan: Tidak ada gambar di '{class_train_path}', lewati kelas ini.")
        continue

    num_test_samples = int(len(images) * test_ratio)

    # Pilih gambar secara acak
    test_images = random.sample(images, num_test_samples)

    # Pindahkan gambar ke folder test
    for img in test_images:
        src_path = os.path.join(class_train_path, img)
        dest_path = os.path.join(class_test_path, img)

        shutil.copy2(src_path, dest_path)

print("Dataset uji berhasil dibuat!")
# Out:
# Dataset uji berhasil dibuat!

# %%
import os

test_path = "/content/drive/MyDrive/SKRIPSI/test"

# Periksa jumlah gambar per kelas
for class_name in os.listdir(test_path):
    class_test_path = os.path.join(test_path, class_name)
    num_images = len(os.listdir(class_test_path))
    print(f"Kelas {class_name}: {num_images} gambar")
# Out:
# Kelas Kaca: 391 gambar
# Kelas Kardus: 302 gambar
# Kelas Kertas: 411 gambar
# Kelas Logam: 395 gambar
# Kelas Plastik: 424 gambar
# Kelas Residu: 607 gambar

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Buat ImageDataGenerator untuk dataset uji
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    shuffle=False
)

# Prediksi model pada dataset uji
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=-1)

# Ambil label sebenarnya
y_true = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Buat Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Print Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_labels))
# Out:
# Found 2530 images belonging to 6 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 40s 132ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         Kaca       0.98      0.96      0.97       391
#       Kardus       0.95      0.96      0.96       302
#       Kertas       0.96      0.97      0.97       411
#        Logam       0.97      0.95      0.96       395
#      Plastik       0.94      0.94      0.94       424
#       Residu       0.96      0.97      0.96       607
#
#     accuracy                           0.96      2530
#    macro avg       0.96      0.96      0.96      2530
# weighted avg       0.96      0.96      0.96      2530
